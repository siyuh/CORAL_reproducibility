# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import scanpy as sc
import anndata
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap


adata_rna = sc.read_h5ad('../..//coral_storage/Data_SpatialGlue/Dataset13_Simulation1/adata_RNA.h5ad')
adata = adata_rna.copy()
adata.obs['ground_truth'] = 1*np.array(adata.obsm['spfac'][:,0] + 2*adata.obsm['spfac'][:,1] + 3*adata.obsm['spfac'][:,2] + 4*adata.obsm['spfac'][:,3])
adata.obs['annotation'] = adata.obs['ground_truth']
annotation_mapping = {
    1.0: 'factor1',
    2.0: 'factor2',
    3.0: 'factor3',
    4.0: 'factor4',
    0.0: 'backgr'  
}
adata.obs['annotation'] = adata.obs['annotation'].map(annotation_mapping)

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = ['#81b29a', '#3d405b', '#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata.obs['annotation'].unique()):
    
    plt.scatter(adata.obsm['spatial'][adata.obs['annotation']==i,0],
                adata.obsm['spatial'][adata.obs['annotation']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
adata_totalvi = sc.read_h5ad('../../coral_storage/coral_results/simulation/totalvi_simu1.h5ad')
adata_spatialglue = sc.read_h5ad('../../coral_storage/coral_results/simulation/spatialglue_simu1.h5ad')
adata_coral = sc.read_h5ad('../../coral_storage/coral_results/simulation/coral_simu1.h5ad')
adata_miso = sc.read_h5ad('../../coral_storage/coral_results/simulation/miso_simu1.h5ad')

adata_M1 = sc.read_h5ad('../../coral_storage/coral_results/simulation/M1_simu1.h5ad')
adata_M2 = sc.read_h5ad('../../coral_storage/coral_results/simulation/M2_simu1.h5ad')
adata_pca = sc.read_h5ad('../../coral_storage/coral_results/simulation/pcaconcat_simu1.h5ad')

adata_downsized_M1 = sc.read_h5ad('../../coral_storage/coral_results/simulation/downsized_m1.h5ad')
# Out:
# /home/users/siyuhe/.local/lib/python3.12/site-packages/anndata/_core/anndata.py:1793: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = ['#81b29a', '#3d405b','#f4f1de', '#f2cc8f', '#e07a5f', ]
for j,i in enumerate(adata_pca.obs['leiden'].unique()):
    
    plt.scatter(adata_pca.obsm['spatial'][adata_pca.obs['leiden']==i,0],
                adata_pca.obsm['spatial'][adata_pca.obs['leiden']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = [  '#f2cc8f','#f4f1de','#3d405b', '#e07a5f','#81b29a' ]
for j,i in enumerate(adata_downsized_M1.obs['leiden'].unique()):
    
    plt.scatter(adata_downsized_M1.obsm['spatial'][adata_downsized_M1.obs['leiden']==i,0],
                adata_downsized_M1.obsm['spatial'][adata_downsized_M1.obs['leiden']==i,1],
                s=40,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = ['#3d405b','#81b29a',  '#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_M2.obs['leiden'].unique()):
    
    plt.scatter(adata_M2.obsm['spatial'][adata_M2.obs['leiden']==i,0],
                adata_M2.obsm['spatial'][adata_M2.obs['leiden']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = ['#3d405b','#81b29a',  '#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_M1.obs['leiden'].unique()):
    
    plt.scatter(adata_M1.obsm['spatial'][adata_M1.obs['leiden']==i,0],
                adata_M1.obsm['spatial'][adata_M1.obs['leiden']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = [ '#f2cc8f','#3d405b', '#81b29a', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_totalvi.obs['leiden'].unique()):
    
    plt.scatter(adata_totalvi.obsm['spatial'][adata_totalvi.obs['leiden']==i,0],
                adata_totalvi.obsm['spatial'][adata_totalvi.obs['leiden']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = [ '#81b29a', '#3d405b','#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_miso.obs['leiden'].unique()):
    
    plt.scatter(adata_miso.obsm['spatial'][adata_miso.obs['leiden']==i,0],
                adata_miso.obsm['spatial'][adata_miso.obs['leiden']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
from umap import UMAP

umap_model = UMAP(n_neighbors=30, min_dist=0.2, n_components=2, random_state=42)
z_umap = umap_model.fit_transform(adata_totalvi.obsm['X_totalVI'])
adata_totalvi.obsm['umap'] = z_umap 


plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = [ '#f2cc8f','#3d405b', '#81b29a', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_totalvi.obs['leiden'].unique()):
    
    plt.scatter(adata_totalvi.obsm['umap'][adata_totalvi.obs['leiden']==i,0],
                adata_totalvi.obsm['umap'][adata_totalvi.obs['leiden']==i,1],
                s=5.5,
                alpha = 0.2,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# /home/users/siyuhe/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Text(0, 0.5, '')

# %%
from umap import UMAP

umap_model = UMAP(n_neighbors=30, min_dist=0.2, n_components=2, random_state=42)
z_umap = umap_model.fit_transform(adata_miso.obsm['miso'])
adata_miso.obsm['umap'] = z_umap 


plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = [ '#81b29a', '#3d405b','#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_miso.obs['leiden'].unique()):
    
    plt.scatter(adata_miso.obsm['umap'][adata_miso.obs['leiden']==i,0],
                adata_miso.obsm['umap'][adata_miso.obs['leiden']==i,1],
                s=5.5,
                alpha = 0.2,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# /home/users/siyuhe/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Text(0, 0.5, '')

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = ['#81b29a','#3d405b',  '#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_spatialglue.obs['leiden'].unique()):
    
    plt.scatter(adata_spatialglue.obsm['spatial'][adata_spatialglue.obs['leiden']==i,0],
                adata_spatialglue.obsm['spatial'][adata_spatialglue.obs['leiden']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
adata_spatialglue
# Out:
# AnnData object with n_obs × n_vars = 1296 × 1000
#     obs: 'cluster', 'leiden'
#     var: 'mean', 'std'
#     uns: 'adj_spatial', 'cluster_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors'
#     obsm: 'SpatialGlue', 'adj_feature', 'alpha', 'alpha_omics1', 'alpha_omics2', 'emb_latent_omics1', 'emb_latent_omics2', 'feat', 'nsfac', 'spatial', 'spfac', 'umap'
#     varm: 'nsload', 'spload'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
from umap import UMAP

umap_model = UMAP(n_neighbors=30, min_dist=0.2, n_components=2, random_state=42)
z_umap = umap_model.fit_transform(adata_spatialglue.obsm['SpatialGlue'])
adata_spatialglue.obsm['umap'] = z_umap 

plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = [ '#f2cc8f','#3d405b', '#81b29a', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_spatialglue.obs['leiden'].unique()):
    
    plt.scatter(adata_spatialglue.obsm['umap'][adata_spatialglue.obs['leiden']==i,0],
                adata_spatialglue.obsm['umap'][adata_spatialglue.obs['leiden']==i,1],
                s=5.5,
                alpha = 0.2,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# /home/users/siyuhe/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Text(0, 0.5, '')

# %%
plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = ['#81b29a','#3d405b',  '#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_coral.obs['cluster'].unique()):
    
    plt.scatter(adata_coral.obsm['spatial'][adata_coral.obs['cluster']==i,0],
                adata_coral.obsm['spatial'][adata_coral.obs['cluster']==i,1],
                s=5.5,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
adata.obs
# Out:
#       ground_truth annotation
# 529            2.0    factor2
# 478            1.0    factor1
# 234            2.0    factor2
# 64             2.0    factor2
# 1087           3.0    factor3
# ...            ...        ...
# 956            0.0     backgr
# 734            0.0     backgr
# 1104           4.0    factor4
# 398            1.0    factor1
# 1190           3.0    factor3
#
# [1296 rows x 2 columns]

# %%
from umap import UMAP

umap_model = UMAP(n_neighbors=30, min_dist=0.2, n_components=2, random_state=42)
z_umap = umap_model.fit_transform(adata_coral.X)
adata_coral.obsm['umap'] = z_umap 

plt.subplots(1,1,figsize= (2,2),dpi=800)

color_list = ['#81b29a','#3d405b',  '#f2cc8f', '#e07a5f', '#f4f1de']
for j,i in enumerate(adata_coral.obs['cluster'].unique()):
    
    plt.scatter(adata_coral.obsm['umap'][adata_coral.obs['cluster']==i,0],
                adata_coral.obsm['umap'][adata_coral.obs['cluster']==i,1],
                s=5.5,
                alpha = 0.2,
                color = color_list[j]
               )
#plt.legend(adata.obs['annotation'].unique(),bbox_to_anchor=(1.01,0.8))
plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
# Out:
# /home/users/siyuhe/.local/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Text(0, 0.5, '')

# %%
from sklearn.metrics import homogeneity_score, mutual_info_score, v_measure_score, \
    adjusted_rand_score, adjusted_mutual_info_score, normalized_mutual_info_score
from scipy.stats import f_oneway
def calculate_scores(adata, annotation_key, adata_method, leiden_key):
    true_labels = adata.obs[annotation_key]
    predicted_labels = adata_method.obs[leiden_key]

    if not true_labels.index.equals(predicted_labels.index):
        predicted_labels = predicted_labels.reindex(true_labels.index)

    if predicted_labels.isnull().any():
        raise ValueError("Reindexing resulted in NaN values.")

    homogeneity = homogeneity_score(true_labels, predicted_labels)
    mi_score = mutual_info_score(true_labels, predicted_labels)
    v_measure = v_measure_score(true_labels, predicted_labels)
    ari_score = adjusted_rand_score(true_labels, predicted_labels)
    ami_score = adjusted_mutual_info_score(true_labels, predicted_labels)
    nmi_score = normalized_mutual_info_score(true_labels, predicted_labels)

    scores = {
        'Homogeneity': homogeneity,
        'Mutual_info': mi_score,
        'V_measure': v_measure,
        'AMI': ami_score,
        'NMI': nmi_score,
        'ARI': ari_score
    }

    return scores


def calculate_anova_for_metrics(bootstrapped_scores, methods_label):
    """
    Perform ANOVA for each metric across all methods.

    Parameters:
    - bootstrapped_scores: Nested dictionary with bootstrapped scores for each metric and method.
    - methods_label: List of method names.

    Returns:
    - anova_results: Dictionary with metric as key and (F-statistic, p-value) as value.
    """
    anova_results = {}
    for metric, method_scores in bootstrapped_scores.items():
        # Collect scores for this metric across all methods
        #print(metric)
        metric_data = [method_scores[method] for method in methods_label]
        
        # Perform ANOVA
        f_stat, p_val = f_oneway(*metric_data)
        anova_results[metric] = (f_stat, p_val)
    return anova_results


def bootstrap_anova_with_calculate_scores(adata, annotation_key, methods_label, methods, leiden_keys, n_bootstrap=1000):
    """
    Perform bootstrapping to calculate ANOVA p-values for each metric using the calculate_scores function.

    Parameters:
    - adata: AnnData object containing the true annotations.
    - annotation_key: Key for the true annotations in adata.obs.
    - methods_label: List of method names.
    - methods: List of AnnData objects for clustering methods.
    - leiden_keys: List of keys for cluster labels in methods.obs.
    - n_bootstrap: Number of bootstrap iterations.

    Returns:
    - anova_results: Dictionary where each key is a metric, and the value is (F-statistic, p-value).
    - bootstrapped_scores: Dictionary of dictionaries with scores for each metric and method.
    """
    # Initialize bootstrapped scores for all metrics
    metrics = ['Homogeneity', 'Mutual_info', 'V_measure', 'AMI', 'NMI', 'ARI']
    bootstrapped_scores = {metric: {label: [] for label in methods_label} for metric in metrics}
    for _ in range(n_bootstrap):
        # Resample indices with replacement
        indices = np.random.choice(adata.obs[annotation_key].index, size=len(adata.obs), replace=True)
        true_resampled = adata.obs[annotation_key].loc[indices]

        # Loop through each method and calculate scores
        for label, method, leiden_key in zip(methods_label, methods, leiden_keys):
            predicted_resampled = method.obs[leiden_key].reindex(indices)
            if predicted_resampled.isnull().any():
                continue  # Skip if NaNs exist

            # Calculate metrics using the resampled labels
            resampled_scores = {
                'Homogeneity': homogeneity_score(true_resampled, predicted_resampled),
                'Mutual_info': mutual_info_score(true_resampled, predicted_resampled),
                'V_measure': v_measure_score(true_resampled, predicted_resampled),
                'AMI': adjusted_mutual_info_score(true_resampled, predicted_resampled),
                'NMI': normalized_mutual_info_score(true_resampled, predicted_resampled),
                'ARI': adjusted_rand_score(true_resampled, predicted_resampled),
            }

            # Append each metric's score to the corresponding list
            for metric, score in resampled_scores.items():
                bootstrapped_scores[metric][label].append(score)
    anova_results = calculate_anova_for_metrics(bootstrapped_scores, methods_label)

    return bootstrapped_scores, anova_results





methods_label = ['Modality 1', 'Modality 2', 'PCA concat', 'totalVI', 'SpatialGlue', 'MISO','Coral']
leiden_keys = ['cluster', 'cluster', 'cluster', 'leiden', 'leiden', 'leiden','cluster']

# Call the function
adata_miso.obs_names = adata_coral.obs_names
bootstrapped_scores, anova_results = bootstrap_anova_with_calculate_scores(
    adata=adata, annotation_key='annotation',
    methods_label=methods_label, methods=[adata_M1, adata_M2, adata_pca, 
                                          adata_totalvi, adata_spatialglue, 
                                          adata_miso, adata_coral],
    leiden_keys=leiden_keys, n_bootstrap=100
)

# Display ANOVA results
for metric, (f_stat, p_val) in anova_results.items():
    print(f"{metric}: F-statistic = {f_stat:.3f}, p-value = {p_val:.3e}")
# Out:
# Homogeneity: F-statistic = 62823.954, p-value = 0.000e+00
# Mutual_info: F-statistic = 50212.331, p-value = 0.000e+00
# V_measure: F-statistic = 62677.424, p-value = 0.000e+00
# AMI: F-statistic = 62585.441, p-value = 0.000e+00
# NMI: F-statistic = 62677.424, p-value = 0.000e+00
# ARI: F-statistic = 86806.869, p-value = 0.000e+00

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert bootstrapped_scores to a long-format DataFrame
bootstrapped_scores_long = []

for metric, methods in bootstrapped_scores.items():
    for method, scores in methods.items():
        bootstrapped_scores_long.extend([
            {'Metric': metric, 'Method': method, 'Score': score} for score in scores
        ])

bootstrapped_scores_df = pd.DataFrame(bootstrapped_scores_long)

# Define custom colors for methods
custom_colors = ['#90e0ef','#00b4d8','#8ab17d','#d9ae94', '#cdc7e5', 'pink','#FF7F50']
custom_palette = dict(zip(['Modality 1', 'Modality 2', 'PCA concat', 'totalVI', 'SpatialGlue','MISO', 'Coral'], custom_colors))

# Plot using Seaborn
plt.figure(figsize=(6,3.2), dpi=800)
sns.barplot(
    x='Metric', y='Score', hue='Method', data=bootstrapped_scores_df, 
    palette=custom_palette, errorbar='sd' ,
    err_kws={'linewidth': 1.8}
)

plt.xlabel('')
plt.ylabel('Score')
plt.legend(title='Method', bbox_to_anchor=(1.02, 1))
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey's HSD Test for each metric
def perform_tukey_test(bootstrapped_scores, methods_label):
    """
    Perform Tukey's HSD test for each metric using bootstrapped scores.

    Parameters:
    - bootstrapped_scores: Nested dictionary of scores for each metric and method.
    - methods_label: List of method names.

    Returns:
    - tukey_results: Dictionary where each key is a metric, and the value is the Tukey test summary.
    """
    tukey_results = {}

    for metric, method_scores in bootstrapped_scores.items():
        # Create long-format data for Tukey's HSD
        scores = []
        methods = []
        for method, method_scores_list in method_scores.items():
            scores.extend(method_scores_list)
            methods.extend([method] * len(method_scores_list))

        # Perform Tukey's HSD test
        tukey = pairwise_tukeyhsd(endog=scores, groups=methods, alpha=0.05)
        tukey_results[metric] = tukey.summary()

    return tukey_results


# Call the Tukey function
tukey_results = perform_tukey_test(bootstrapped_scores, methods_label)

# Display Tukey's HSD results
for metric, summary in tukey_results.items():
    print(f"\nTukey's HSD for {metric}:\n{summary}")
# Out:
# Tukey's HSD for Homogeneity:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#    group1      group2   meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#       Coral        MISO  -0.3907    0.0 -0.3952 -0.3862   True
#       Coral  Modality 1  -0.5774    0.0 -0.5819 -0.5729   True
#       Coral  Modality 2  -0.6609    0.0 -0.6654 -0.6564   True
#       Coral  PCA concat    -0.33    0.0 -0.3345 -0.3255   True
#       Coral SpatialGlue  -0.0065 0.0004  -0.011  -0.002   True
#       Coral     totalVI   -0.559    0.0 -0.5635 -0.5546   True
#        MISO  Modality 1  -0.1867    0.0 -0.1912 -0.1822   True
#        MISO  Modality 2  -0.2702    0.0 -0.2747 -0.2657   True
#        MISO  PCA concat   0.0607    0.0  0.0562  0.0652   True
#        MISO SpatialGlue   0.3842    0.0  0.3797  0.3887   True
#        MISO     totalVI  -0.1683    0.0 -0.1728 -0.1638   True
#  Modality 1  Modality 2  -0.0835    0.0  -0.088  -0.079   True
# ...
